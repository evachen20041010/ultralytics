# %%
from collections import defaultdict
from pathlib import Path

import cv2
import numpy as np
from shapely.geometry import Polygon
from shapely.geometry.point import Point

from ultralytics import YOLO
from ultralytics.utils.files import increment_path
from ultralytics.utils.plotting import Annotator, colors

track_history = defaultdict(list)

current_region = None

# %%
def run(
    weights="../models/v6.pt",
    source="../Khare_testvideo_02.mp4",
    device="0",
    view_img=True,
    save_img=True,
    exist_ok=False,
    classes=[0],
    line_thickness=2,
    track_thickness=2,
    region_thickness=2,
    stationary_threshold=5  # Threshold for determining if a car is stationary
):
    vid_frame_count = 0

    # Check source path
    if not Path(source).exists():
        raise FileNotFoundError(f"Source path '{source}' does not exist.")

    # Setup Model
    model = YOLO(f"{weights}")
    model.to("cuda") if device == "0" else model.to("cpu")

    # Extract classes names
    names = model.model.names

    # Video setup
    videocapture = cv2.VideoCapture(source)
    frame_width, frame_height = int(videocapture.get(3)), int(videocapture.get(4))
    fps, fourcc = int(videocapture.get(5)), cv2.VideoWriter_fourcc(*"mp4v")

    # Define the counting region to cover the entire frame
    counting_regions = [
        {
            "name": "YOLOv8 Polygon Region",
            "polygon": Polygon([(0, 0), (frame_width, 0), (frame_width, frame_height), (0, frame_height)]),  # Full screen
            "counts": 0,
            "dragging": False,
            "region_color": (255, 42, 4),  # BGR Value
            "text_color": (255, 255, 255),  # Region Text Color
        },
    ]

    # Output setup
    save_dir = increment_path(Path("ultralytics_rc_output") / "exp", exist_ok)
    save_dir.mkdir(parents=True, exist_ok=True)
    video_writer = cv2.VideoWriter(str(save_dir / f"{Path(source).stem}.mp4"), fourcc, fps, (frame_width, frame_height))

    # Iterate over video frames
    while videocapture.isOpened():
        success, frame = videocapture.read()
        if not success:
            break
        vid_frame_count += 1

        # Extract the results
        results = model.track(frame, persist=True, classes=classes)

        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu()
            track_ids = results[0].boxes.id.int().cpu().tolist()
            clss = results[0].boxes.cls.cpu().tolist()

            annotator = Annotator(frame, line_width=line_thickness, example=str(names))

            for box, track_id, cls in zip(boxes, track_ids, clss):
                annotator.box_label(box, str(names[cls]), color=colors(cls, True))
                bbox_center = (box[0] + box[2]) / 2, (box[1] + box[3]) / 2  # Bbox center

                track = track_history[track_id]  # Tracking Lines plot
                track.append((float(bbox_center[0]), float(bbox_center[1])))
                if len(track) > 30:
                    track.pop(0)
                points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                cv2.polylines(frame, [points], isClosed=False, color=colors(cls, True), thickness=track_thickness)

                # Check if detection is stationary
                if len(track) > 1:
                    movement = np.linalg.norm(np.array(track[-1]) - np.array(track[0]))
                    if movement < stationary_threshold:
                        # Check if detection inside region
                        for region in counting_regions:
                            if region["polygon"].contains(Point((bbox_center[0], bbox_center[1]))):
                                region["counts"] += 1

        # Draw regions (Polygons/Rectangles)
        for region in counting_regions:
            region_label = str(region["counts"])
            region_color = region["region_color"]
            region_text_color = region["text_color"]

            polygon_coords = np.array(region["polygon"].exterior.coords, dtype=np.int32)
            centroid_x, centroid_y = int(region["polygon"].centroid.x), int(region["polygon"].centroid.y)

            text_size, _ = cv2.getTextSize(
                region_label, cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.7, thickness=line_thickness
            )
            text_x = centroid_x - text_size[0] // 2
            text_y = centroid_y + text_size[1] // 2
            cv2.rectangle(
                frame,
                (text_x - 5, text_y - text_size[1] - 5),
                (text_x + text_size[0] + 5, text_y + 5),
                region_color,
                -1,
            )
            cv2.putText(
                frame, region_label, (text_x, text_y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, region_text_color, line_thickness
            )
            cv2.polylines(frame, [polygon_coords], isClosed=True, color=region_color, thickness=region_thickness)

        if view_img:
            if vid_frame_count == 1:
                cv2.namedWindow("Ultralytics YOLOv8 Region Counter Movable")
            cv2.imshow("Ultralytics YOLOv8 Region Counter Movable", frame)

        if save_img:
            video_writer.write(frame)

        for region in counting_regions:  # Reinitialize count for each region
            region["counts"] = 0

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    del vid_frame_count
    video_writer.release()
    videocapture.release()
    cv2.destroyAllWindows()

# %%
def main():
    """Main function."""
    run()

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 14 cars, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 0.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 17.5ms
# Speed: 0.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.3ms
# Speed: 1.1ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.7ms
# Speed: 1.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.1ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.7ms
# Speed: 0.0ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.3ms
# Speed: 1.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 16.1ms
# Speed: 0.0ms preprocess, 16.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.2ms
# Speed: 1.0ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.9ms
# Speed: 1.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.4ms
# Speed: 1.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.4ms
# Speed: 0.0ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 14.0ms
# Speed: 1.2ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 14.5ms
# Speed: 0.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
